# %%
! pip install pandas_ta
# Out:
# ...
#   Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------------------------- -------------- 1.8/2.8 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 9.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    -- ------------------------------------- 1.8/30.3 MB 10.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 3.7/30.3 MB 8.7 MB/s eta 0:00:04
#    ------ --------------------------------- 5.2/30.3 MB 8.6 MB/s eta 0:00:03
#    --------- ------------------------------ 7.3/30.3 MB 8.9 MB/s eta 0:00:03
#    ------------ --------------------------- 9.2/30.3 MB 8.9 MB/s eta 0:00:03
#    -------------- ------------------------- 11.3/30.3 MB 9.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 13.4/30.3 MB 9.2 MB/s eta 0:00:02
# ...

# %%
import pandas_ta as ta
